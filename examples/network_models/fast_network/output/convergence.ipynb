# %% [markdown]
# # Importing package

# %%
from os import path
import sys
sys.path.append(path.abspath('/Users/igor.koval/Documents/Work/RiemAlzh/src/utils/visu_toolbox/utils'))

from convergence_visu import convergence_visu

# %matplotlib inline

# %% [markdown]
# # Reading files

# %%
convergence_file = "convergence_params.txt"

# %% [markdown]
# # Loading the visualization

# %%
conv = convergence_visu(convergence_file)

# %%
conv.name_variables()
# Out:
# ['Noise', 'TauVar', 'Delta#1', 'TauMean', 'NuMean', 'KsiMean', 'KsiVar', 'NuVar', 'Position', 'S#1', 'Beta#1']

# %%
conv.plot(["Noise", "Position"])

# %%
conv.plot(["TauMean", "TauVar"])

# %%
conv.plot(["KsiMean", "KsiVar"])

# %%
conv.plot(["NuMean", "NuVar"])

# %%
conv.plot(["Delta#1", "Beta#1", "S#1"])
